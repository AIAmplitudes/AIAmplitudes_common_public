# %% [markdown]
# Welcome to the public version of the "AI for Amplitudes" library! This is a library designed for exploratory data analysis and high-level function calls used in the ChromoBoot, ScatterBrain, and ScatterSeek projects. To start, import the package.
#
# AIAA_common_public is intended to be relatively static, while the (currently-private) AIAA_common_dev is intended to be more dynamic and contain more test features/collaborative development.

# %%
import aiamplitudes_common_public

# %% [markdown]
# You can load the Phi2 or Phi3 symbols at up to 6 loops (uncompressed) or up to 8 loops (compressed in the original quad/oct format). Note that this format stores the backspace token FIRST, distinct from the generalized sewing form, which stores F@{string}@B. Adding support for sewing and adding additional symbols will come in a future release!

# %%
from aiamplitudes_common_public import Phi2Symb, Phi3Symb

# %%
Phi2Symb(2)
# Out:
# {'aaae': 16,
#  'aaaf': 16,
#  'bbbd': 16,
#  'bbbf': 16,
#  'cccd': 16,
#  'ccce': 16,
#  'bddd': 8,
#  'cddd': 8,
#  'ceee': 8,
#  'aeee': 8,
#  'afff': 8,
#  'bfff': 8}

# %%
from aiamplitudes_common_public import frontbackspaces
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from aiamplitudes_common_public import frontbackspaces
#
# ImportError: cannot import name 'frontbackspaces' from 'aiamplitudes_common_public' (/home/garrett/AIAA_fresh/AIAmplitudes_common_public/src/aiamplitudes_common_public/__init__.py)

# %%
Phi2Symb(6, "quad")
# Out:
# {'Br_4_0aaaaacbc': 384,
#  'Br_4_0aaaaacbd': -28416,
#  'Br_4_0aaaaaccb': -20544,
#  'Br_4_0aaaaaccc': 20544,
#  'Br_4_0aaaaaccd': 28416,
#  'Br_4_0aaaaacdb': -15360,
#  'Br_4_0aaaaacdc': 15360,
#  'Br_4_0aaaaacec': 15744,
#  'Br_4_0aaaaaeab': 196224,
#  'Br_4_0aaaaaeac': -196224,
#  'Br_4_0aaaaaecb': -196224,
#  'Br_4_0aaaaaecc': 196992,
#  'Br_4_0aaaaaecd': 583680,
#  'Br_4_0aaaaaafb': -802176,
#  'Br_4_0aaaaabab': -20928,
#  'Br_4_0aaaaabac': 20928,
#  'Br_4_0aaaaabbb': 20544,
#  'Br_4_0aaaaabbc': -20544,
#  'Br_4_0aaaaabbd': 28416,
#  'Br_4_0aaaaabcb': 384,
#  'Br_4_0aaaaabcc': -384,
#  'Br_4_0aaaaabcd': -28416,
#  'Br_4_0aaaaabdb': 15360,
#  'Br_4_0aaaaabdc': -15360,
#  'Br_4_0aaaaabfb': 15744,
#  'Br_4_0aaaaacab': 20928,
#  'Br_4_0aaaaacac': -20928,
#  'Br_4_0aaaaacbb': -384,
#  'Br_4_0aaaaaabb': -20160,
#  'Br_4_0aaaaaabc': 20160,
#  'Br_4_0aaaaaacb': 20160,
#  'Br_4_0aaaaaacc': -20160,
#  'Br_4_0aaaaaaec': -802176,
#  'Br_4_0aaaabfbb': -384,
#  'Br_4_0aaaabfbc': -384,
# ...

# %% [markdown]
# We can also load the "d-ray" polynomials as either polynomials or tables of coefficients.

# %%
from aiamplitudes_common_public import Phi2Symb, Phi3Symb

# %% [markdown]
# We can load the front-space or back-space of the Phi2 symbol, calculated up to a given weight,
# in permissive or restrictive format:

# %% [markdown]
# We can load the relations of a given type: integrability, triple, Steinmann adjacancy, etc.:

# %% [markdown]
# The "Symbol" object is a dictionary-wrapper with elementwise addition and support for high-level operators like the shuffle product, stuffle product, and coproduct. These functions are located in the AIAA_common_dev package, which will ultimately be merged into common_public.

# %% [markdown]
# Let's calculate the conditions required to perform generalized sewing:

# %% [markdown]
# Let's generate 100 instances of the integrability relation using the phi2 symbol.
#
#
# We can preprocess (that is- first find all terms that satisfy the relation, THEN sample),
# preprocess only arguments (for complicated relations/operations such as "multi-strikeout",
# the combinatorics might be expensive), or choose not to preprocess and generate keys/instances one by one.
#
# For lower loops/weights where we are generating large numbers of instances,
# preprocessing dramatically speeds up the generation, but this drops off as the number of terms
# in the symbol becomes much larger than the number of instances generated.

# %% [markdown]
# Let's apply some operators to the 6-loop symbol:

# %% [markdown]
# Plot how terms connect to each other using a chord graph:
